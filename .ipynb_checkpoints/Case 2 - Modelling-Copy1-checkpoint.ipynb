# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %matplotlib inline

# %% [markdown]
# ## Question: What should be the total brazilian soybeans, soybean_meal, and corn export forecasts, in tons, for the next 11 years (2020-2030)? We’re mostly interested in the annual forecast

# %%
#Now we get the covariates data
covariates_df = pd.read_excel('covariates.xlsx')
covariates_df.head()
# Out:
#    year  price_soybeans  price_corn  price_soybean_meal   gdp_china  \
# 0  1979             NaN         NaN                 NaN  100.000000
# 1  1980      100.000000  100.000000          100.000000  107.900000
# 2  1981       98.525508  103.888308           99.805440  113.402900
# 3  1982       83.406192   85.986430           86.596956  123.609161
# 4  1983       97.851743  108.168059           98.663318  136.958950
#
#      gdp_iran  gpd_netherlands   gdp_spain  gdp_thailand   gdp_world  \
# 0  100.000000              NaN  100.000000    100.000000  100.000000
# 1   81.200000       100.000000  101.200000    104.600000  102.100000
# 2   74.216800        99.500000  100.795200    110.771400  104.039900
# 3   83.939201        98.206500  102.004742    116.753056  104.664139
# 4   95.522811        99.974217  103.738823    123.291227  107.594735
#
#     gdp_egypt   gdp_japan  gdp_vietnam
# 0  100.000000  100.000000   100.000000
# 1  103.400000  103.200000    96.500000
# 2  105.674800  107.534400   102.097000
# 3  113.389060  111.083035   110.468954
# 4  123.480687  114.970941   118.312250

# %% [markdown]
# #### Since our covariates dataset contains basically economic growth rates of many countries and commodities prices, we should select only the countries that are most important in terms of export volume regarding each product

# %% [markdown]
# As seen on previous analysis, we should consider a recent time frame due to decreases on exports depeding upon the product. I'll be using the last 5 years to determine the most important destinations.

# %%
#Reading data
exports_df = pd.read_csv('data_comexstat.csv', encoding='latin-1')

#Parsing date column to datetime
exports_df['date'] = pd.to_datetime(exports_df['date'], format='%Y-%m-%d')

#Adding Year Reference Column
exports_df['year'] = exports_df['date'].dt.to_period('Y')
exports_df['year'] = exports_df['year'].astype(str).astype(int)

#Grouping by total exports by year
#exports_df = exports_df.groupby(['product', 'year'])['tons'].sum().reset_index()

display(exports_df.head())
# Out:
#         date product state        country    type   route    tons       usd  \
# 0 1997-01-01    corn    ES  United States  Import     Sea  44.045  113029.0
# 1 1997-01-01    corn    GO      Argentina  Import  Ground  54.000   36720.0
# 2 1997-01-01    corn    GO        Bolivia  Export  Ground   0.200     180.0
# 3 1997-01-01    corn    GO  United States  Export     Sea   3.488    5688.0
# 4 1997-01-01    corn    MG      Argentina  Import  Ground  27.000   18630.0
#
#    year
# 0  1997
# 1  1997
# 2  1997
# 3  1997
# 4  1997

# %% [markdown]
# #### The exports dataset starts at 1997 whilst the covariates dataset starts at 1979. We should delete the rows that do not have a matching period.

# %%
#Dropping rows before 1997
covariates_df = covariates_df[covariates_df['year']>=1997]
covariates_df['year'] = covariates_df['year'].astype(str).astype(int) #parsing to join with covariates df

#Index by year
covariates_df = covariates_df.set_index('year')

display(covariates_df.head())

display(covariates_df.tail(11)) #showing next 11 years data as required
# Out:
#       price_soybeans  price_corn  price_soybean_meal   gdp_china    gdp_iran  \
# year
# 1997      105.761629   93.204180          124.012650  560.722750  106.976296
# 1998       84.160030   80.831375           77.421718  604.459124  109.008846
# 1999       65.928699   71.823936           67.601747  651.002477  109.335873
# 2000       68.993825   70.173520           82.934920  706.337687  116.880048
# 2001       63.605148   71.279115           80.029143  765.670053  117.815088
#
#       gpd_netherlands   gdp_spain  gdp_thailand   gdp_world   gdp_egypt  \
# year
# 1997       152.738204  156.728085    345.124057  173.936618  218.683678
# 1998       159.916900  163.780849    318.894628  178.458970  235.084954
# 1999       167.912745  171.478549    333.563781  184.883493  249.425136
# 2000       174.965080  180.223955    348.574151  193.757900  262.894093
# 2001       178.989277  187.252689    360.425672  198.601848  272.095387
#
#        gdp_japan  gdp_vietnam
# year
# 1997  180.133771   299.095195
# 1998  178.152299   316.442716
# 1999  177.617842   331.631967
# 2000  182.591142   354.182940
# 2001  183.321506   378.621563
#       price_soybeans  price_corn  price_soybean_meal    gdp_china    gdp_iran  \
# year
# 2020      116.920726  127.345508          145.243944  3685.667312  169.949912
# 2021      121.166259  130.855976          148.695213  4024.748705  175.218360
# 2022      125.565952  134.463215          152.228491  4230.010888  181.266859
# 2023      130.125404  138.169893          155.845726  4441.511433  187.576609
# 2024      134.850415  141.978752          159.548913  4663.587005  194.212029
# 2025      139.746996  145.892607          163.340095  4892.102768  201.152295
# 2026      145.203519  150.142281          167.410250  5126.923701  208.285085
# 2027      150.660041  154.391956          171.480405  5362.762191  215.582431
# 2028      156.116564  158.641630          175.550560  5604.086489  223.147862
# 2029      161.573086  162.891304          179.620715  5850.666295  230.993806
# 2030      167.029608  167.140979          183.690870  6102.244946  239.096864
#
#       gpd_netherlands   gdp_spain  gdp_thailand   gdp_world   gdp_egypt  \
# year
# 2020       211.249225  225.919534    675.556744  379.328745  604.776444
# 2021       217.586702  235.634074    716.765705  401.318974  621.710185
# 2022       220.415329  238.697317    741.508301  415.172417  643.171485
# 2023       223.721559  242.277776    767.319592  429.624226  665.559753
# 2024       227.301104  246.154221    794.463105  444.821949  689.103567
# 2025       231.278874  250.461920    822.853648  460.717888  713.729033
# 2026       235.511277  255.045373    852.031753  477.054784  739.037617
# 2027       239.985991  259.891235    881.883004  493.768577  764.930077
# 2028       244.665718  264.959114    912.830910  511.096390  791.773755
# 2029       249.436700  270.125817    944.926309  529.066687  819.612750
# 2030       254.300715  275.393270    978.073487  547.625878  848.364039
#
#        gdp_japan  gdp_vietnam
# year
# 2020  201.141214  1240.856229
# 2021  207.175450  1327.716165
# 2022  208.832854  1395.429689
# 2023  210.503517  1465.201174
# 2024  212.187545  1538.461232
# 2025  213.885045  1613.845833
# 2026  215.382241  1691.310433
# 2027  216.889916  1769.110713
# 2028  218.408146  1848.720695
# 2029  219.937003  1930.064405
# 2030  221.476562  2013.057175

# %%
def filter_last_n_years(df, n_years):
    filtered_df = df[df['year']>=df['year'].max()- (n_years-1)] #N year diff-1
    filtered_df = filtered_df.reset_index(drop=True)
    return filtered_df

# %%
def filter_df_by_product(df, product):
    filtered_df = df[df['product'] == product].reset_index(drop=True)
    return filtered_df

# %%
def last_n_years_top_n_destinations_df(exports_df, product, n_years, top_n):
    last_n_years_exports_df = filter_last_n_years(exports_df,n_years)
    last_n_years_product_df = filter_df_by_product(last_n_years_exports_df, product)
    grouped_sum = pd.DataFrame(last_n_years_product_df.groupby("country")["tons"].sum())
    top_n_destinations_df =  grouped_sum.nlargest(top_n, 'tons').reset_index()
    return top_n_destinations_df

# %% [markdown]
# # 1. Soybeans

# %%
top_5_soybean_destinations_df = last_n_years_top_n_destinations_df(exports_df=exports_df, 
                                                                   product='soybeans', 
                                                                   n_years=5, 
                                                                   top_n=5)
top_5_soybean_destinations_df.head()
# Out:
#        country          tons
# 0        China  2.551818e+08
# 1        Spain  1.008667e+07
# 2     Thailand  7.765262e+06
# 3  Netherlands  7.431224e+06
# 4         Iran  5.804947e+06

# %% [markdown]
# #### These are the top destinations of Brazillian Soybeans. Now we have to check if there's multicollinearity between the growth of each country or between commodities prices.

# %% [markdown]
# First, let's create a way to visualize the total annual exports of each product and concatenate the data to our covariate dataset.

# %%
def get_annual_exports_by_product(exports_df, product):
    product_df = exports_df[exports_df['product']==product]
    grouped_sum = pd.DataFrame(product_df.groupby("year")["tons"].sum())
    grouped_sum = grouped_sum.reset_index()
    return grouped_sum

# %%
def plot_annual_exports(product_df, color):
    fig, ax = plt.subplots(1,1, figsize = (15,7))
    #fig.suptitle(f"{product.capitalize()} Exports by {period.capitalize()} (Million tons)")
    
    
    ax.plot(product_df['year'], product_df['tons'], c=color)

    #setting y scale to million tons
    ax.get_yaxis().set_major_formatter(
        FuncFormatter(lambda x, p: format(int(x)/1_000_000, ',')))

    #Adding labels to the graph
    for x,y in zip(product_df['year'],product_df['tons']):
        label = "{:.2f}".format(y/1_000_000)

        plt.annotate(label, # text
                     (x,y), # text coordinates
                     textcoords="offset points", # text position
                     xytext=(0,5), # offset distance from text to points (x,y)
                     ha='center') # horizontal alignment -> [left, right, center]

# %%
def concatenate_product_covariate_df(product_df, covariates_df):
    product_df = product_df.set_index('year')
    full_df = pd.concat([product_df, covariates_df], axis=1)
    return full_df

# %%
#Soybeans annual exports
soybean_annual_exports = get_annual_exports_by_product(exports_df, 'soybeans')
display(soybean_annual_exports.tail())
plot_annual_exports(soybean_annual_exports, color='b')
# Out:
#     year          tons
# 18  2015  5.462754e+07
# 19  2016  5.195593e+07
# 20  2017  6.826031e+07
# 21  2018  8.233441e+07
# 22  2019  7.044439e+07

# %%
full_soybean_df = concatenate_product_covariate_df(soybean_annual_exports, covariates_df)

display(full_soybean_df.head())
display(full_soybean_df.tail(11)) #displaying years to be forecast
# Out:
#               tons  price_soybeans  price_corn  price_soybean_meal  \
# year
# 1997  9.215246e+06      105.761629   93.204180          124.012650
# 1998  9.507719e+06       84.160030   80.831375           77.421718
# 1999  8.678062e+06       65.928699   71.823936           67.601747
# 2000  1.153252e+07       68.993825   70.173520           82.934920
# 2001  1.533649e+07       63.605148   71.279115           80.029143
#
#        gdp_china    gdp_iran  gpd_netherlands   gdp_spain  gdp_thailand  \
# year
# 1997  560.722750  106.976296       152.738204  156.728085    345.124057
# 1998  604.459124  109.008846       159.916900  163.780849    318.894628
# 1999  651.002477  109.335873       167.912745  171.478549    333.563781
# 2000  706.337687  116.880048       174.965080  180.223955    348.574151
# gdp_thailand        0.944138        0.675014    0.610743            0.774115
# gdp_world           0.955477        0.651535    0.590587            0.754949
# gdp_egypt           0.949844        0.653173    0.596944            0.753194
# gdp_japan           0.917929        0.564933    0.505285            0.661212
# gdp_vietnam         0.974088        0.594334    0.531649            0.713140
#
#                     gdp_china  gdp_iran  gpd_netherlands  gdp_spain  \
# tons                 0.967442  0.802580         0.890407   0.777469
# price_soybeans       0.628736  0.713271         0.591827   0.536325
# price_corn           0.563795  0.656157         0.563586   0.511971
# price_soybean_meal   0.745486  0.738898         0.661442   0.569418
# gdp_china            1.000000  0.869017         0.925597   0.811712
# gdp_iran             0.869017  1.000000         0.931660   0.931974
# gpd_netherlands      0.925597  0.931660         1.000000   0.962298
# gdp_spain            0.811712  0.931974         0.962298   1.000000
# gdp_thailand         0.985866  0.922673         0.953311   0.875599
# gdp_world            0.994176  0.909397         0.954593   0.863216
# gdp_egypt            0.992944  0.904522         0.957379   0.864404
# gdp_japan            0.932470  0.894654         0.943080   0.892725
# gdp_vietnam          0.997462  0.870871         0.938276   0.834793
#
#                     gdp_thailand  gdp_world  gdp_egypt  gdp_japan  gdp_vietnam
# tons                    0.944138   0.955477   0.949844   0.917929     0.974088
# price_soybeans          0.675014   0.651535   0.653173   0.564933     0.594334
# price_corn              0.610743   0.590587   0.596944   0.505285     0.531649
# price_soybean_meal      0.774115   0.754949   0.753194   0.661212     0.713140
# gdp_china               0.985866   0.994176   0.992944   0.932470     0.997462
# gdp_iran                0.922673   0.909397   0.904522   0.894654     0.870871
# gpd_netherlands         0.953311   0.954593   0.957379   0.943080     0.938276
# gdp_spain               0.875599   0.863216   0.864404   0.892725     0.834793
# gdp_thailand            1.000000   0.996385   0.991130   0.962580     0.986762
# gdp_world               0.996385   1.000000   0.996595   0.955766     0.994115
# gdp_egypt               0.991130   0.996595   1.000000   0.935941     0.992781
# gdp_japan               0.962580   0.955766   0.935941   1.000000     0.943678
# gdp_vietnam             0.986762   0.994115   0.992781   0.943678     1.000000

# %% [markdown]
# ### As we can see on the correlation matrix, many of the 'gdp measures' show high levels of correlation which is an indication of multicollinearity. We can double check it by the Variance inflation factor.

# %%
# define two data frames one before the drop and one after the drop
full_soybean_df_before = full_soybean_df.loc[:'2019'] #filtering out the years that do not contain export data

# the VFI does expect a constant term in the data, so we need to add one using the add_constant method
X1 = sm.tools.add_constant(full_soybean_df_before)

# create the series for both
series_before = pd.Series([variance_inflation_factor(X1.values, i) for i in range(X1.shape[1])], index=X1.columns)

# display the series
display(series_before)
# Out:
# const                 16722.459835
# tons                     52.757921
# price_soybeans          225.734130
# price_corn               47.407378
# price_soybean_meal      146.492953
# gdp_china              8693.962963
# gdp_iran                 70.125059
# gpd_netherlands         410.381563
# gdp_spain               336.052558
# gdp_thailand           1388.419889
# gdp_world              3113.687443
# gdp_egypt              1943.594946
# gdp_japan               143.102100
# gdp_vietnam            2887.500020
# dtype: float64

# %% [markdown]
# A general recommendation is that if any of our variables come back with a **value of 5 or higher, then they should be removed from the model.**

# %% [markdown]
# ### As we can see, there are many variables with high values of Variance inflation factor. If we drop the highly correlated columns we should see a decrease on these numbers.

# %%
'''
Soybeans Top Destinations

China
Spain
Thailand
Netherlands
Iran

'''

columns_to_keep = [
    'gdp_china',
    'gdp_spain',
    'gdp_thailand',
    'gpd_netherlands',
    'gdp_iran',
    
    'price_soybeans',
    'price_corn',
]

columns_to_drop = list(set(full_soybean_df.columns).symmetric_difference(set(columns_to_keep)))


full_soybean_df_after = full_soybean_df.loc[:'2019'].drop(columns_to_drop, axis = 1)

X2 = sm.tools.add_constant(full_soybean_df_after)

series_after = pd.Series([variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])], index=X2.columns)

display(series_after)
# Out:
# const              2762.564204
# price_soybeans       19.854856
# price_corn           14.765771
# gdp_china           205.757675
# gdp_iran             21.508764
# gpd_netherlands     147.894743
# gdp_spain           115.554641
# gdp_thailand        194.988511
# dtype: float64

# %% [markdown]
# ### The numbers decreased a lot as expected, but are still too high (Ideally we should have numbers <= 5). After some trial and error, the optimal combination of variables for soybeans is:

# %%
'''
Soybeans Top Destinations

China
Spain
Thailand
Netherlands
Iran

'''

columns_to_keep = [
    'gdp_china',
    #'gdp_spain',
    #'gdp_thailand',
    #'gpd_netherlands',
    #'gdp_iran',
    
    'price_soybeans',
    #'price_corn',
]

columns_to_drop = list(set(full_soybean_df.columns).symmetric_difference(set(columns_to_keep)))


full_soybean_df_after = full_soybean_df.loc[:'2019'].drop(columns_to_drop, axis = 1)

X2 = sm.tools.add_constant(full_soybean_df_after)

series_after = pd.Series([variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])], index=X2.columns)

display(series_after)
# Out:
# const             9.530790
# price_soybeans    1.653738
# gdp_china         1.653738
# dtype: float64

# %% [markdown]
# ##### We'll use as input of our models the variables: price_soybeans, gdp_china and gdp_spain
# ***
# ### Another way to visualize our data to check for multicollinearity is to scatter plot for each variable in our dataset against another variable. This allows visualizing the correlation of one variable across all the other variables in the dataset. There shouldn't be any strong trends in the scatter matrix as this would be identifying correlated variables.

# %%
# define the plot
pd.plotting.scatter_matrix(full_soybean_df_after, alpha = 1, figsize = (15, 7))

# show the plot
plt.show()

# %% [markdown]
# # Building the Model

# %%
# define our input variable (X) & output variable
columns_to_drop.remove('tons') #we do not need to delete our target value now

full_soybean_df_after = full_soybean_df.loc[:'2019'].drop(columns_to_drop, axis = 1)

X = full_soybean_df_after.drop('tons', axis = 1)
Y = full_soybean_df_after[['tons']]

# Split X and y into X_
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=1)

# %%
# define our input
X2 = sm.add_constant(X)

# create a OLS model
model = sm.OLS(Y, X2)

# fit the data
est = model.fit()

# %%
# print out a summary
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   tons   R-squared:                       0.967
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     289.5
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           1.72e-15
# Time:                        23:12:04   Log-Likelihood:                -380.85
# No. Observations:                  23   AIC:                             767.7
# Df Residuals:                      20   BIC:                             771.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           4.321e+06    2.6e+06      1.665      0.111   -1.09e+06    9.74e+06
# price_soybeans  -1.11e+05   2.59e+04     -4.286      0.000   -1.65e+05    -5.7e+04
# gdp_china       2.344e+04   1110.542     21.106      0.000    2.11e+04    2.58e+04
# ==============================================================================
# Omnibus:                        9.690   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.182
# Skew:                           0.871   Prob(JB):                       0.0101
# Kurtosis:                       5.559   Cond. No.                     6.26e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Get multiple predictions
y_predict = est.predict(sm.add_constant(X_test))

predicted_years = y_test.index.tolist()

# Show the first 5 predictions
for index, point in enumerate(y_predict):
    observed_value = round(y_test.iloc[index]['tons']/1000000, 2)
    predicted_value = round(point/1000000, 2)
    print(f" Year {predicted_years[index]} | Model prediction: {predicted_value} M tons | Observed value: {observed_value} | M tons | Dif: {round(observed_value-predicted_value,2)}")
#y_predict[:5]
# Out:
#  Year 2017 | Model prediction: 64.71 M tons | Observed value: 68.26 | M tons | Dif: 3.55
#  Year 2014 | Model prediction: 46.95 M tons | Observed value: 46.27 | M tons | Dif: -0.68
#  Year 2000 | Model prediction: 13.22 M tons | Observed value: 11.53 | M tons | Dif: -1.69
#  Year 2010 | Model prediction: 33.42 M tons | Observed value: 29.17 | M tons | Dif: -4.25
#  Year 2016 | Model prediction: 59.68 M tons | Observed value: 51.96 | M tons | Dif: -7.72

# %% [markdown]
# ### As we can see, the model does not show a lot of difference when predicting the data within the test sample. We can proceed with the prediction of the next 11 years now.

# %%
soybeans_predict_period_df = full_soybean_df.loc['2020':].drop(columns_to_drop, axis = 1)
X_forecast = soybeans_predict_period_df.drop('tons', axis = 1)
X_forecast
# Out:
#       price_soybeans    gdp_china
# year
# 2020      116.920726  3685.667312
# 2021      121.166259  4024.748705
# 2022      125.565952  4230.010888
# 2023      130.125404  4441.511433
# 2024      134.850415  4663.587005
# 2025      139.746996  4892.102768
# 2026      145.203519  5126.923701
# 2027      150.660041  5362.762191
# 2028      156.116564  5604.086489
# 2029      161.573086  5850.666295
# 2030      167.029608  6102.244946

# %%
X_forecast = sm.add_constant(X_forecast)
final_forecast = pd.DataFrame(est.predict(X_forecast), columns=['tons'])
final_forecast = final_forecast.reset_index()

# %%
plot_annual_exports(final_forecast, 'b')

# %% [markdown]
# ### For the next products, I'll skip most of the visualizations and go straightforward to the predictions

# %% [markdown]
# # Soybean Meal

# %%
top_5_soybean_destinations_df = last_n_years_top_n_destinations_df(exports_df=exports_df, 
                                                                   product='soybean_meal', 
                                                                   n_years=5, 
                                                                   top_n=5)
top_5_soybean_destinations_df.head()
# Out:
#        country          tons
# 0  Netherlands  1.360811e+07
# 1     Thailand  8.891496e+06
# 2       France  8.329131e+06
# 3    Indonesia  8.076603e+06
# 4  South Korea  7.455673e+06

# %%
#Soybean Meal annual exports
soybean_annual_exports = get_annual_exports_by_product(exports_df, 'soybean_meal')
display(soybean_annual_exports.tail())
plot_annual_exports(soybean_annual_exports, color='g')
# Out:
#     year          tons
# 18  2015  1.482773e+07
# 19  2016  1.444459e+07
# 20  2017  1.417837e+07
# 21  2018  1.667020e+07
# 22  2019  1.653359e+07

# %%
full_soybean_meal_df = concatenate_product_covariate_df(soybean_annual_exports, covariates_df)

display(full_soybean_meal_df.head())
display(full_soybean_meal_df.tail(11)) #displaying years to be forecast
# Out:
#               tons  price_soybeans  price_corn  price_soybean_meal  \
# year
# 1997  1.025757e+07      105.761629   93.204180          124.012650
# 1998  1.010982e+07       84.160030   80.831375           77.421718
# 1999  1.012678e+07       65.928699   71.823936           67.601747
# 2000  9.154139e+06       68.993825   70.173520           82.934920
# 2001  1.080122e+07       63.605148   71.279115           80.029143
X2 = sm.tools.add_constant(full_soybean_meal_df_after)

series_after = pd.Series([variance_inflation_factor(X2.values, i) for i in range(X2.shape[1])], index=X2.columns)


display(series_after)
# Out:
# const                 127.110525
# price_soybean_meal      1.777794
# gpd_netherlands         1.777794
# dtype: float64

# %%
# define our input variable (X) & output variable
columns_to_drop.remove('tons') #we do not need to delete our target value now

full_soybean_meal_df_after = full_soybean_meal_df.loc[:'2019'].drop(columns_to_drop, axis = 1)

X = full_soybean_meal_df_after.drop('tons', axis = 1)
Y = full_soybean_meal_df_after[['tons']]

# Split X and y into X_
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=1)

# %%
# define our intput
X2 = sm.add_constant(X)

# create a OLS model
model = sm.OLS(Y, X2)

# fit the data
est = model.fit()

# %%
# print out a summary
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   tons   R-squared:                       0.704
# Model:                            OLS   Adj. R-squared:                  0.675
# Method:                 Least Squares   F-statistic:                     23.83
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):           5.09e-06
# Time:                        23:12:05   Log-Likelihood:                -351.57
# No. Observations:                  23   AIC:                             709.1
# Df Residuals:                      20   BIC:                             712.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -3.086e+06   2.65e+06     -1.163      0.259   -8.62e+06    2.45e+06
# price_soybean_meal  1728.7807   7118.502      0.243      0.811   -1.31e+04    1.66e+04
# gpd_netherlands     8.199e+04   1.64e+04      5.014      0.000    4.79e+04    1.16e+05
# ==============================================================================
# Omnibus:                        0.001   Durbin-Watson:                   0.964
# Prob(Omnibus):                  0.999   Jarque-Bera (JB):                0.150
# Skew:                           0.015   Prob(JB):                        0.928
# Kurtosis:                       2.605   Cond. No.                     2.69e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Get multiple predictions
y_predict = est.predict(sm.add_constant(X_test))

predicted_years = y_test.index.tolist()

# Show the first 5 predictions
for index, point in enumerate(y_predict):
    observed_value = round(y_test.iloc[index]['tons']/1000000, 2)
    predicted_value = round(point/1000000, 2)
    print(f" Year {predicted_years[index]} | Model prediction: {predicted_value} M tons | Observed value: {observed_value} | M tons | Dif: {round(observed_value-predicted_value,2)}")
# Out:
#  Year 2017 | Model prediction: 15.11 M tons | Observed value: 14.18 | M tons | Dif: -0.93
#  Year 2014 | Model prediction: 13.99 M tons | Observed value: 13.72 | M tons | Dif: -0.27
#  Year 2000 | Model prediction: 11.4 M tons | Observed value: 9.15 | M tons | Dif: -2.25
#  Year 2010 | Model prediction: 13.59 M tons | Observed value: 13.71 | M tons | Dif: 0.12
#  Year 2016 | Model prediction: 14.61 M tons | Observed value: 14.44 | M tons | Dif: -0.17

# %%
soybean_meal_predict_period_df = full_soybean_meal_df.loc['2020':].drop(columns_to_drop, axis = 1)
X_forecast = soybean_meal_predict_period_df.drop('tons', axis = 1)
X_forecast
# Out:
#       price_soybean_meal  gpd_netherlands
# year
# 2020          145.243944       211.249225
# 2021          148.695213       217.586702
# 2022          152.228491       220.415329
# 2023          155.845726       223.721559
# 2024          159.548913       227.301104
# 2025          163.340095       231.278874
# 2026          167.410250       235.511277
# 2027          171.480405       239.985991
# 2028          175.550560       244.665718
# 2029          179.620715       249.436700
# 2030          183.690870       254.300715

# %%
X_forecast = sm.add_constant(X_forecast)
final_forecast = pd.DataFrame(est.predict(X_forecast), columns=['tons'])
final_forecast = final_forecast.reset_index()

# %%
plot_annual_exports(final_forecast, 'b')
